# %% [markdown]
# ## 🧠 Lesson 4: Level 4-Mastering while Loops
# ### ISBE After-School Program
# ----
# **Student Name:** ____________________________  <br>
# **School:**  _________________________________ <br>
# **Date:** ________________________________ <br>
# ---
# ### 🎯 Learning Objectives
# - By the end of this lesson, you will be able to:
# - Repeat instructions using multiple loops (nested loops)
# - Create advanced patterns and shapes using Python
# - Understand how inner and outer loops work together
# ---
# ### 🧩 Lesson Overview
# In this lesson, we will learn how to repeat actions using a for loop. We will practice creating and organizing shapes using both single and nested (multiple) loops. By the end of the lesson, you will understand how to write programs more efficiently and effectively.

# %% [markdown]
# ### Practice with Jupyter Cells
# * **Switch to Markdown**: Use this setting to write notes or documentation.
# * **Switch to Code**: Use this setting to write and execute Python code.
# * **Execute a Cell**: Press **Ctrl + Enter** or **Shift + Enter** to run the selected cell.

# %% [markdown]
# ### Importing Necessary Modules from Python Libraries
# Modules are pre-written code packages that provide specific functionality in Python. They make programming easier by offering ready-to-use functions and classes, so you don’t have to write everything from scratch.
# Why use modules?
#
# * They save time and reduce errors.
# * They provide powerful tools for tasks like math, visualization, and interactivity.
#
# ---

# %%
import matplotlib.patches as patches  # Import Matplotlib patches for plotting shapes
import shapes_module as sm  # Import custom module for defining plot area
import numpy as np # Import numpy for mathematical function

# %% [markdown]
# ### Arranging Shapes with Two for Loops 🎨
# By using **for loops**, we can tell the computer to draw shapes automatically in rows and columns.
# * The outer loop controls one direction (like rows)
# * The inner loop controls another direction (like columns)
# * This lets us create grids, patterns, and complex designs easily without drawing each shape by hand.

# %%
fig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 1:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson4_level4_c1.png" alt="Description" width="25%"/>

# %%
fig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 2:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson4_level4_c2.png" alt="Description" width="25%"/>

# %%
ig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 3:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson3_level3_c2.png" alt="Description" width="20%"/>

# %%
ig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 4:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson3_level3_c3.png" alt="Description" width="20%"/>

# %%
ig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 5:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson4_level4_c3.png" alt="Description" width="20%"/>

# %%
ig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 6:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson4_level4_c4.png" alt="Description" width="20%"/>
# ---

# %%
ig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 7:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson4_level4_c5.png" alt="Description" width="20%"/>

# %%
ig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 8:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson4_level4_c6.png" alt="Description" width="15%"/>

# %%
ig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 9:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson4_level4_c7.png" alt="Description" width="15%"/>

# %%
ig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 10:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson4_level4_c8.png" alt="Description" width="15%"/>

# %%
ig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 11:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson4_level4_c9.png" alt="Description" width="15%"/>

# %%
ig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 13:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson4_level4_c11.png" alt="Description" width="15%"/>

# %%
ig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# ### Challenge 14:
# Modify the parameters to recreate the image shown below
#
# <img src="lesson4_level4_c12.png" alt="Description" width="15%"/>

# %%
ig, ax = sm.setup_figure('Arranging Shape in two dimensions');

i = 0
while i < 11: 
    x = i%2  # using modulo operator to determine even and odd number
    if x==0:  # if condition
        clr = 'red'
    else:
        clr = 'blue'
 
    circle = patches.Circle((i+0.5, 2.5), 0.5, facecolor=clr)
    ax.add_patch(circle)
    i = i +1

# %% [markdown]
# # Wow! You’ve Mastered if Statement and while Loops! 🎉
#
# ## Congratulations! 🏆
#
# You can now:
#
# 1. Use if statements with confidence.
# 2. Use while loops with confidence.
# 3. Combine for loops with conditions.
# 4. 🚀 Move on to game development and try more fun exercises!
